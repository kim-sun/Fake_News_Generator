# %% [markdown]
# #### Observe that we can get news of a day with the link format:
# http://news.ltn.com.tw/list/newspaper/politics/20181231
# #### We need a list of date string in the date range we want.

# %%
from datetime import datetime, timedelta

start_date = "2017-01-01"
stop_date = "2019-06-21"

start = datetime.strptime(start_date, "%Y-%m-%d") # datetime.strptime(date_string, format) return datetime
stop = datetime.strptime(stop_date, "%Y-%m-%d")

dates = list() #dates=[]
while start <= stop:
    dates.append(start.strftime('%Y%m%d')) # Return a string representing the date and time
    start = start + timedelta(days=1)

# %% [markdown]
# #### Now write a function to parse the HTML response, return the data we want(title, content, ...etc).

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
def process_document(document, date, tag):
    
    nodes = document.select('ul.list > li') # 選擇ul的class list 底下的li
    data = list()

    for li in nodes:

        # check if is empty element
        if li.select_one('a') == None: # 沒有<a></a> 是我們不要的
            continue # select_one = finds only the first tag that matches a selector

        # get link
        li_link = 'http://news.ltn.com.tw/' + li.select_one('a')['href'] #把網址取出來

        # request for document
        li_res = requests.get(li_link) 
        li_doc = bs(li_res.text, 'lxml')

        # get date
        li_date = datetime.strptime(date, "%Y%m%d").strftime('%Y-%m-%d') # 轉回去字串 "2018-07-01"

        #get title
        li_title = li.select_one('p').get_text() #取得 title

        #get content
        li_content = ""
        for ele in li_doc.select('div.news_content > p'): # 在文章中的div.text下的p
            if not 'appE1121' in ele.get('class', []): # 不要想看更多新聞
                
                li_content += ele.get_text() 

        # append new row
        data.append({
            'date' : li_date,
            'title': li_title,
            'link' : li_link,
            'content' : li_content,
            'tags' : tag
        })
    return data

# %% [markdown]
# #### Crawl over the news on the site, store the data in variable "all_data" .

# %%
cnt = 0
all_data = list()
for date in dates:
    print('start crawling :', date)
    res = requests.get('https://news.ltn.com.tw/list/newspaper/entertainment/' + date) # ex: http://news.ltn.com.tw/list/newspaper/politics/20181231
    doc = bs(res.text, 'lxml') # lxml為處理HTML的編譯器套件，該網頁經過BeautifulSoup內lxml編輯器解析的結果
    data = process_document(doc, date, 'entertainment')
    all_data += data
# Out:
# start crawling : 20170101
# start crawling : 20170102
# start crawling : 20170103
# start crawling : 20170104
# start crawling : 20170105
# start crawling : 20170106
# start crawling : 20170107
# start crawling : 20170108
# start crawling : 20170109
# start crawling : 20170110
# start crawling : 20170111
# start crawling : 20170112
# start crawling : 20170113
# start crawling : 20170114
# start crawling : 20170115
# start crawling : 20170116
# start crawling : 20170117
# start crawling : 20170118
# start crawling : 20170119
# start crawling : 20170120
# start crawling : 20170121
# start crawling : 20170122
# start crawling : 20170123
# start crawling : 20170124
# start crawling : 20170125
# start crawling : 20170126
# start crawling : 20170127
# start crawling : 20170128
# start crawling : 20170129
# start crawling : 20170130
# start crawling : 20170131
# start crawling : 20170201
# start crawling : 20170202
# start crawling : 20170203
# start crawling : 20170204
# start crawling : 20170205
# start crawling : 20170206
# start crawling : 20170207
# start crawling : 20170208
# start crawling : 20170209
# start crawling : 20170210
# start crawling : 20170211
# start crawling : 20170212
# start crawling : 20170213
# start crawling : 20170214
# start crawling : 20170215
# start crawling : 20170216
# start crawling : 20170217
# start crawling : 20170218
# start crawling : 20170219
# start crawling : 20170220
# start crawling : 20170221
# start crawling : 20170222
# start crawling : 20170223
# start crawling : 20170224
# start crawling : 20170225
# start crawling : 20170226
# start crawling : 20170227
# start crawling : 20170228
# start crawling : 20170301
# start crawling : 20170302
# start crawling : 20170303
# start crawling : 20170304
# start crawling : 20170305
# start crawling : 20170306
# start crawling : 20170307
# start crawling : 20170308
# start crawling : 20170309
# start crawling : 20170310
# start crawling : 20170311
# start crawling : 20170312
# start crawling : 20170313
# start crawling : 20170314
# start crawling : 20170315
# start crawling : 20170316
# start crawling : 20170317
# start crawling : 20170318
# start crawling : 20170319
# start crawling : 20170320
# start crawling : 20170321
# start crawling : 20170322
# start crawling : 20170323
# start crawling : 20170324
# start crawling : 20170325
# start crawling : 20170326
# start crawling : 20170327
# start crawling : 20170328
# start crawling : 20170329
# start crawling : 20170330
# start crawling : 20170331
# start crawling : 20170401
# start crawling : 20170402
# start crawling : 20170403
# start crawling : 20170404
# start crawling : 20170405
# start crawling : 20170406
# start crawling : 20170407
# start crawling : 20170408
# start crawling : 20170409
# start crawling : 20170410
# start crawling : 20170411
# start crawling : 20170412
# start crawling : 20170413
# start crawling : 20170414
# start crawling : 20170415
# start crawling : 20170416
# start crawling : 20170417
# start crawling : 20170418
# start crawling : 20170419
# start crawling : 20170420
# start crawling : 20170421
# start crawling : 20170422
# start crawling : 20170423
# start crawling : 20170424
# start crawling : 20170425
# start crawling : 20170426
# start crawling : 20170427
# start crawling : 20170428
# start crawling : 20170429
# start crawling : 20170430
# start crawling : 20170501
# start crawling : 20170502
# start crawling : 20170503
# start crawling : 20170504
# start crawling : 20170505
# start crawling : 20170506
# start crawling : 20170507
# start crawling : 20170508
# start crawling : 20170509
# start crawling : 20170510
# start crawling : 20170511
# start crawling : 20170512
# start crawling : 20170513
# start crawling : 20170514
# start crawling : 20170515
# start crawling : 20170516
# start crawling : 20170517
# start crawling : 20170518
# start crawling : 20170519
# start crawling : 20170520
# start crawling : 20170521
# start crawling : 20170522
# start crawling : 20170523
# start crawling : 20170524
# start crawling : 20170525
# start crawling : 20170526
# start crawling : 20170527
# start crawling : 20170528
# start crawling : 20170529
# start crawling : 20170530
# start crawling : 20170531
# start crawling : 20170601
# start crawling : 20170602
# start crawling : 20170603
# start crawling : 20170604
# start crawling : 20170605
# start crawling : 20170606
# start crawling : 20170607
# start crawling : 20170608
# start crawling : 20170609
# start crawling : 20170610
# start crawling : 20170611
# start crawling : 20170612
# start crawling : 20170613
# start crawling : 20170614
# start crawling : 20170615
# start crawling : 20170616
# start crawling : 20170617
# start crawling : 20170618
# start crawling : 20170619
# start crawling : 20170620
# start crawling : 20170621
# start crawling : 20170622
# start crawling : 20170623
# start crawling : 20170624
# start crawling : 20170625
# start crawling : 20170626
# start crawling : 20170627
# start crawling : 20170628
# start crawling : 20170629
# start crawling : 20170630
# start crawling : 20170701
# start crawling : 20170702
# start crawling : 20170703
# start crawling : 20170704
# start crawling : 20170705
# start crawling : 20170706
# start crawling : 20170707
# start crawling : 20170708
# start crawling : 20170709
# start crawling : 20170710
# start crawling : 20170711
# start crawling : 20170712
# start crawling : 20170713
# start crawling : 20170714
# start crawling : 20170715
# start crawling : 20170716
# start crawling : 20170717
# start crawling : 20170718
# start crawling : 20170719
# start crawling : 20170720
# start crawling : 20170721
# start crawling : 20170722
# start crawling : 20170723
# start crawling : 20170724
# start crawling : 20170725
# start crawling : 20170726
# start crawling : 20170727
# start crawling : 20170728
# start crawling : 20170729
# start crawling : 20170730
# start crawling : 20170731
# start crawling : 20170801
# start crawling : 20170802
# start crawling : 20170803
# start crawling : 20170804
# start crawling : 20170805
# start crawling : 20170806
# start crawling : 20170807
# start crawling : 20170808
# start crawling : 20170809
# start crawling : 20170810
# start crawling : 20170811
# start crawling : 20170812
# start crawling : 20170813
# start crawling : 20170814
# start crawling : 20170815
# start crawling : 20170816
# start crawling : 20170817
# start crawling : 20170818
# start crawling : 20170819
# start crawling : 20170820
# start crawling : 20170821
# start crawling : 20170822
# start crawling : 20170823
# start crawling : 20170824
# start crawling : 20170825
# start crawling : 20170826
# start crawling : 20170827
# start crawling : 20170828
# start crawling : 20170829
# start crawling : 20170830
# start crawling : 20170831
# start crawling : 20170901
# start crawling : 20170902
# start crawling : 20170903
# start crawling : 20170904
# start crawling : 20170905
# start crawling : 20170906
# start crawling : 20170907
# start crawling : 20170908
# start crawling : 20170909
# start crawling : 20170910
# start crawling : 20170911
# start crawling : 20170912
# start crawling : 20170913
# start crawling : 20170914
# start crawling : 20170915
# start crawling : 20170916
# start crawling : 20170917
# start crawling : 20170918
# start crawling : 20170919
# start crawling : 20170920
# start crawling : 20170921
# start crawling : 20170922
# start crawling : 20170923
# start crawling : 20170924
# start crawling : 20170925
# start crawling : 20170926
# start crawling : 20170927
# start crawling : 20170928
# start crawling : 20170929
# start crawling : 20170930
# start crawling : 20171001
# start crawling : 20171002
# start crawling : 20171003
# start crawling : 20171004
# start crawling : 20171005
# start crawling : 20171006
# start crawling : 20171007
# start crawling : 20171008
# start crawling : 20171009
# start crawling : 20171010
# start crawling : 20171011
# start crawling : 20171012
# start crawling : 20171013
# start crawling : 20171014
# start crawling : 20171015
# start crawling : 20171016
# start crawling : 20171017
# start crawling : 20171018
# start crawling : 20171019
# start crawling : 20171020
# start crawling : 20171021
# start crawling : 20171022
# start crawling : 20171023
# start crawling : 20171024
# start crawling : 20171025
# start crawling : 20171026
# start crawling : 20171027
# start crawling : 20171028
# start crawling : 20171029
# start crawling : 20171030
# start crawling : 20171031
# start crawling : 20171101
# start crawling : 20171102
# start crawling : 20171103
# start crawling : 20171104
# start crawling : 20171105
# start crawling : 20171106
# start crawling : 20171107
# start crawling : 20171108
# start crawling : 20171109
# start crawling : 20171110
# start crawling : 20171111
# start crawling : 20171112
# start crawling : 20171113
# start crawling : 20171114
# start crawling : 20171115
# start crawling : 20171116
# start crawling : 20171117
# start crawling : 20171118
# start crawling : 20171119
# start crawling : 20171120
# start crawling : 20171121
# start crawling : 20171122
# start crawling : 20171123
# start crawling : 20171124
# start crawling : 20171125
# start crawling : 20171126
# start crawling : 20171127
# start crawling : 20171128
# start crawling : 20171129
# start crawling : 20171130
# start crawling : 20171201
# start crawling : 20171202
# start crawling : 20171203
# start crawling : 20171204
# start crawling : 20171205
# start crawling : 20171206
# start crawling : 20171207
# start crawling : 20171208
# start crawling : 20171209
# start crawling : 20171210
# start crawling : 20171211
# start crawling : 20171212
# start crawling : 20171213
# start crawling : 20171214
# start crawling : 20171215
# start crawling : 20171216
# start crawling : 20171217
# start crawling : 20171218
# start crawling : 20171219
# start crawling : 20171220
# start crawling : 20171221
# start crawling : 20171222
# start crawling : 20171223
# start crawling : 20171224
# start crawling : 20171225
# start crawling : 20171226
# start crawling : 20171227
# start crawling : 20171228
# start crawling : 20171229
# start crawling : 20171230
# start crawling : 20171231
# start crawling : 20180101
# start crawling : 20180102
# start crawling : 20180103
# start crawling : 20180104
# start crawling : 20180105
# start crawling : 20180106
# start crawling : 20180107
# start crawling : 20180108
# start crawling : 20180109
# start crawling : 20180110
# start crawling : 20180111
# start crawling : 20180112
# start crawling : 20180113
# start crawling : 20180114
# start crawling : 20180115
# start crawling : 20180116
# start crawling : 20180117
# start crawling : 20180118
# start crawling : 20180119
# start crawling : 20180120
# start crawling : 20180121
# start crawling : 20180122
# start crawling : 20180123
# start crawling : 20180124
# start crawling : 20180125
# start crawling : 20180126
# start crawling : 20180127
# start crawling : 20180128
# start crawling : 20180129
# start crawling : 20180130
# start crawling : 20180131
# start crawling : 20180201
# start crawling : 20180202
# start crawling : 20180203
# start crawling : 20180204
# start crawling : 20180205
# start crawling : 20180206
# start crawling : 20180207
# start crawling : 20180208
# start crawling : 20180209
# start crawling : 20180210
# start crawling : 20180211
# start crawling : 20180212
# start crawling : 20180213
# start crawling : 20180214
# start crawling : 20180215
# start crawling : 20180216
# start crawling : 20180217
# start crawling : 20180218
# start crawling : 20180219
# start crawling : 20180220
# start crawling : 20180221
# start crawling : 20180222
# start crawling : 20180223
# start crawling : 20180224
# start crawling : 20180225
# start crawling : 20180226
# start crawling : 20180227
# start crawling : 20180228
# start crawling : 20180301
# start crawling : 20180302
# start crawling : 20180303
# start crawling : 20180304
# start crawling : 20180305
# start crawling : 20180306
# start crawling : 20180307
# start crawling : 20180308
# start crawling : 20180309
# start crawling : 20180310
# start crawling : 20180311
# start crawling : 20180312
# start crawling : 20180313
# start crawling : 20180314
# start crawling : 20180315
# start crawling : 20180316
# start crawling : 20180317
# start crawling : 20180318
# start crawling : 20180319
# start crawling : 20180320
# start crawling : 20180321
# start crawling : 20180322
# start crawling : 20180323
# start crawling : 20180324
# start crawling : 20180325
# start crawling : 20180326
# start crawling : 20180327
# start crawling : 20180328
# start crawling : 20180329
# start crawling : 20180330
# start crawling : 20180331
# start crawling : 20180401
# start crawling : 20180402
# start crawling : 20180403
# start crawling : 20180404
# start crawling : 20180405
# start crawling : 20180406
# start crawling : 20180407
# start crawling : 20180408
# start crawling : 20180409
# start crawling : 20180410
# start crawling : 20180411
# start crawling : 20180412
# start crawling : 20180413
# start crawling : 20180414
# start crawling : 20180415
# start crawling : 20180416
# start crawling : 20180417
# start crawling : 20180418
# start crawling : 20180419
# start crawling : 20180420
# start crawling : 20180421
# start crawling : 20180422
# start crawling : 20180423
# start crawling : 20180424
# start crawling : 20180425
# start crawling : 20180426
# start crawling : 20180427
# start crawling : 20180428
# start crawling : 20180429
# start crawling : 20180430
# start crawling : 20180501
# start crawling : 20180502
# start crawling : 20180503
# start crawling : 20180504
# start crawling : 20180505
# start crawling : 20180506
# start crawling : 20180507
# start crawling : 20180508
# start crawling : 20180509
# start crawling : 20180510
# start crawling : 20180511
# start crawling : 20180512
# start crawling : 20180513
# start crawling : 20180514
# start crawling : 20180515
# start crawling : 20180516
# start crawling : 20180517
# start crawling : 20180518
# start crawling : 20180519
# start crawling : 20180520
# start crawling : 20180521
# start crawling : 20180522
# start crawling : 20180523
# start crawling : 20180524
# start crawling : 20180525
# start crawling : 20180526
# start crawling : 20180527
# start crawling : 20180528
# start crawling : 20180529
# start crawling : 20180530
# start crawling : 20180531
# start crawling : 20180601
# start crawling : 20180602
# start crawling : 20180603
# start crawling : 20180604
# start crawling : 20180605
# start crawling : 20180606
# start crawling : 20180607
# start crawling : 20180608
# start crawling : 20180609
# start crawling : 20180610
# start crawling : 20180611
# start crawling : 20180612
# start crawling : 20180613
# start crawling : 20180614
# start crawling : 20180615
# start crawling : 20180616
# start crawling : 20180617
# start crawling : 20180618
# start crawling : 20180619
# start crawling : 20180620
# start crawling : 20180621
# start crawling : 20180622
# start crawling : 20180623
# start crawling : 20180624
# start crawling : 20180625
# start crawling : 20180626
# start crawling : 20180627
# start crawling : 20180628
# start crawling : 20180629
# start crawling : 20180630
# start crawling : 20180701
# start crawling : 20180702
# start crawling : 20180703
# start crawling : 20180704
# start crawling : 20180705
# start crawling : 20180706
# start crawling : 20180707
# start crawling : 20180708
# start crawling : 20180709
# start crawling : 20180710
# start crawling : 20180711
# start crawling : 20180712
# start crawling : 20180713
# start crawling : 20180714
# start crawling : 20180715
# start crawling : 20180716
# start crawling : 20180717
# start crawling : 20180718
# start crawling : 20180719
# start crawling : 20180720
# start crawling : 20180721
# start crawling : 20180722
# start crawling : 20180723
# start crawling : 20180724
# start crawling : 20180725
# start crawling : 20180726
# start crawling : 20180727
# start crawling : 20180728
# start crawling : 20180729
# start crawling : 20180730
# start crawling : 20180731
# start crawling : 20180801
# start crawling : 20180802
# start crawling : 20180803
# start crawling : 20180804
# start crawling : 20180805
# start crawling : 20180806
# start crawling : 20180807
# start crawling : 20180808
# start crawling : 20180809
# start crawling : 20180810
# start crawling : 20180811
# start crawling : 20180812
# start crawling : 20180813
# start crawling : 20180814
# start crawling : 20180815
# start crawling : 20180816
# start crawling : 20180817
# start crawling : 20180818
# start crawling : 20180819
# start crawling : 20180820
# start crawling : 20180821
# start crawling : 20180822
# start crawling : 20180823
# start crawling : 20180824
# start crawling : 20180825
# start crawling : 20180826
# start crawling : 20180827
# start crawling : 20180828
# start crawling : 20180829
# start crawling : 20180830
# start crawling : 20180831
# start crawling : 20180901
# start crawling : 20180902
# start crawling : 20180903
# start crawling : 20180904
# start crawling : 20180905
# start crawling : 20180906
# start crawling : 20180907
# start crawling : 20180908
# start crawling : 20180909
# start crawling : 20180910
# start crawling : 20180911
# start crawling : 20180912
# start crawling : 20180913
# start crawling : 20180914
# start crawling : 20180915
# start crawling : 20180916
# start crawling : 20180917
# start crawling : 20180918
# start crawling : 20180919
# start crawling : 20180920
# start crawling : 20180921
# start crawling : 20180922
# start crawling : 20180923
# start crawling : 20180924
# start crawling : 20180925
# start crawling : 20180926
# start crawling : 20180927
# start crawling : 20180928
# start crawling : 20180929
# start crawling : 20180930
# start crawling : 20181001
# start crawling : 20181002
# start crawling : 20181003
# start crawling : 20181004
# start crawling : 20181005
# start crawling : 20181006
# start crawling : 20181007
# start crawling : 20181008
# start crawling : 20181009
# start crawling : 20181010
# start crawling : 20181011
# start crawling : 20181012
# start crawling : 20181013
# start crawling : 20181014
# start crawling : 20181015
# start crawling : 20181016
# start crawling : 20181017
# start crawling : 20181018
# start crawling : 20181019
# start crawling : 20181020
# start crawling : 20181021
# start crawling : 20181022
# start crawling : 20181023
# start crawling : 20181024
# start crawling : 20181025
# start crawling : 20181026
# start crawling : 20181027
# start crawling : 20181028
# start crawling : 20181029
# start crawling : 20181030
# start crawling : 20181031
# start crawling : 20181101
# start crawling : 20181102
# start crawling : 20181103
# start crawling : 20181104
# start crawling : 20181105
# start crawling : 20181106
# start crawling : 20181107
# start crawling : 20181108
# start crawling : 20181109
# start crawling : 20181110
# start crawling : 20181111
# start crawling : 20181112
# start crawling : 20181113
# start crawling : 20181114
# start crawling : 20181115
# start crawling : 20181116
# start crawling : 20181117
# start crawling : 20181118
# start crawling : 20181119
# start crawling : 20181120
# start crawling : 20181121
# start crawling : 20181122
# start crawling : 20181123
# start crawling : 20181124
# start crawling : 20181125
# start crawling : 20181126
# start crawling : 20181127
# start crawling : 20181128
# start crawling : 20181129
# start crawling : 20181130
# start crawling : 20181201
# start crawling : 20181202
# start crawling : 20181203
# start crawling : 20181204
# start crawling : 20181205
# start crawling : 20181206
# start crawling : 20181207
# start crawling : 20181208
# start crawling : 20181209
# start crawling : 20181210
# start crawling : 20181211
# start crawling : 20181212
# start crawling : 20181213
# start crawling : 20181214
# start crawling : 20181215
# start crawling : 20181216
# start crawling : 20181217
# start crawling : 20181218
# start crawling : 20181219
# start crawling : 20181220
# start crawling : 20181221
# start crawling : 20181222
# start crawling : 20181223
# start crawling : 20181224
# start crawling : 20181225
# start crawling : 20181226
# start crawling : 20181227
# start crawling : 20181228
# start crawling : 20181229
# start crawling : 20181230
# start crawling : 20181231
# start crawling : 20190101
# start crawling : 20190102
# start crawling : 20190103
# start crawling : 20190104
# start crawling : 20190105
# start crawling : 20190106
# start crawling : 20190107
# start crawling : 20190108
# start crawling : 20190109
# start crawling : 20190110
# start crawling : 20190111
# start crawling : 20190112
# start crawling : 20190113
# start crawling : 20190114
# start crawling : 20190115
# start crawling : 20190116
# start crawling : 20190117
# start crawling : 20190118
# start crawling : 20190119
# start crawling : 20190120
# start crawling : 20190121
# start crawling : 20190122
# start crawling : 20190123
# start crawling : 20190124
# start crawling : 20190125
# start crawling : 20190126
# start crawling : 20190127
# start crawling : 20190128
# start crawling : 20190129
# start crawling : 20190130
# start crawling : 20190131
# start crawling : 20190201
# start crawling : 20190202
# start crawling : 20190203
# start crawling : 20190204
# start crawling : 20190205
# start crawling : 20190206
# start crawling : 20190207
# start crawling : 20190208
# start crawling : 20190209
# start crawling : 20190210
# start crawling : 20190211
# start crawling : 20190212
# start crawling : 20190213
# start crawling : 20190214
# start crawling : 20190215
# start crawling : 20190216
# start crawling : 20190217
# start crawling : 20190218
# start crawling : 20190219
# start crawling : 20190220
# start crawling : 20190221
# start crawling : 20190222
# start crawling : 20190223
# start crawling : 20190224
# start crawling : 20190225
# start crawling : 20190226
# start crawling : 20190227
# start crawling : 20190228
# start crawling : 20190301
# start crawling : 20190302
# start crawling : 20190303
# start crawling : 20190304
# start crawling : 20190305
# start crawling : 20190306
# start crawling : 20190307
# start crawling : 20190308
# start crawling : 20190309
# start crawling : 20190310
# start crawling : 20190311
# start crawling : 20190312
# start crawling : 20190313
# start crawling : 20190314
# start crawling : 20190315
# start crawling : 20190316
# start crawling : 20190317
# start crawling : 20190318
# start crawling : 20190319
# start crawling : 20190320
# start crawling : 20190321
# start crawling : 20190322
# start crawling : 20190323
# start crawling : 20190324
# start crawling : 20190325
# start crawling : 20190326
# start crawling : 20190327
# start crawling : 20190328
# start crawling : 20190329
# start crawling : 20190330
# start crawling : 20190331
# start crawling : 20190401
# start crawling : 20190402
# start crawling : 20190403
# start crawling : 20190404
# start crawling : 20190405
# start crawling : 20190406
# start crawling : 20190407
# start crawling : 20190408
# start crawling : 20190409
# start crawling : 20190410
# start crawling : 20190411
# start crawling : 20190412
# start crawling : 20190413
# start crawling : 20190414
# start crawling : 20190415
# start crawling : 20190416
# start crawling : 20190417
# start crawling : 20190418
# start crawling : 20190419
# start crawling : 20190420
# start crawling : 20190421
# start crawling : 20190422
# start crawling : 20190423
# start crawling : 20190424
# start crawling : 20190425
# start crawling : 20190426
# start crawling : 20190427
# start crawling : 20190428
# start crawling : 20190429
# start crawling : 20190430
# start crawling : 20190501
# start crawling : 20190502
# start crawling : 20190503
# start crawling : 20190504
# start crawling : 20190505
# start crawling : 20190506
# start crawling : 20190507
# start crawling : 20190508
# start crawling : 20190509
# start crawling : 20190510
# start crawling : 20190511
# start crawling : 20190512
# start crawling : 20190513
# start crawling : 20190514
# start crawling : 20190515
# start crawling : 20190516
# start crawling : 20190517
# start crawling : 20190518
# start crawling : 20190519
# start crawling : 20190520
# start crawling : 20190521
# start crawling : 20190522
# start crawling : 20190523
# start crawling : 20190524
# start crawling : 20190525
# start crawling : 20190526
# start crawling : 20190527
# start crawling : 20190528
# start crawling : 20190529
# start crawling : 20190530
# start crawling : 20190531
# start crawling : 20190601
# start crawling : 20190602
# start crawling : 20190603
# start crawling : 20190604
# start crawling : 20190605
# start crawling : 20190606
# start crawling : 20190607
# start crawling : 20190608
# start crawling : 20190609
# start crawling : 20190610
# start crawling : 20190611
# start crawling : 20190612
# start crawling : 20190613
# start crawling : 20190614
# start crawling : 20190615
# start crawling : 20190616
# start crawling : 20190617
# start crawling : 20190618
# start crawling : 20190619
# start crawling : 20190620
# start crawling : 20190621

# %% [markdown]
# #### Check the result

# %%
print(all_data[1])
print(len(all_data))
# Out:
# {'date': '2017-01-01', 'title': '蕭敬騰獨厚花蓮 先嗑家鄉包', 'link': 'http://news.ltn.com.tw/news/entertainment/paper/1067350', 'content': '李佳薇希望今年有機會挑戰戲劇。\n（華納提供）〔記者陽昕翰、張釔泠／台北報導〕 「老蕭」蕭敬騰為陪花蓮鄉親跨年，昨天凌晨3點從深圳拉車到香港，先坐早班機飛台北，又趕搭普悠瑪號到花蓮，舟車勞頓幾乎沒睡，他前陣子重感冒，現在仍會喉嚨癢、有痰，經紀人Summer說：「醫生有說至少要一個月的恢復期。」蕭敬騰到花蓮跨年，搶吃公正包子。（喜鵲娛樂提供）老蕭一到花蓮，直呼家鄉空氣很好應該早點來，立刻吃起招牌小吃公正包子， 老蕭的媽媽是花蓮人，老家有活動，他總會盡力參加，前天他得知Hit Fm年度百首單曲出爐，他個人與獅子合唱團的作品，共入圍了5首，心情大好。陳勢安尾牙接到手軟。（華納提供）華納師弟妹李佳薇與陳勢安昨晚也忙著唱跨年，兩人近來尾牙場都接到手軟，李佳薇希望今年有機會挑戰戲劇，陳勢安則想開一場大型演唱會。', 'tags': 'entertainment'}
# 16340

# %% [markdown]
# #### Save as pkl file

# %%
import pickle
with open('liberty_times_entertainment.pkl', 'wb') as f: #寫檔
    pickle.dump(all_data, f) #pickle.dump 存到上述的檔案
